# %%
import pandas as pd
from  sklearn.linear_model import  LinearRegression
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/Users/vashuagarwal/Downloads/BENNETT_things/3rd_sem_bennett/CSET_211_SML/30_days_ml/hp.csv', header= 0,encoding= 'unicode_escape')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-7-2e0283b28cc2> in <module>
# ----> 1 dataset = pd.read_csv('/Users/vashuagarwal/Downloads/BENNETT_things/3rd_sem_bennett/CSET_211_SML/30_days_ml/hp.csv', header= 0,encoding= 'unicode_escape')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
